# %% [markdown]
# # 02 — Preprocessing Demo
#
# **Project:** ROSA Knee AI — AI-Based Knee Bone Segmentation & Surgical Planning
# **Module:** 0 — Medical Imaging Data Foundation
#
# ---
#
# ## ⚠️ PREREQUISITE
#
# **Do NOT run this notebook until you have completed `01_dataset_exploration.ipynb`**
# and confirmed the following:
#
# 1. ✅ You know whether the `.npz` data is CT intensity or segmentation labels
# 2. ✅ You have verified label meanings against dataset documentation
# 3. ✅ You have identified the source CT images (if `.npz` contains only labels)
# 4. ✅ You know the spatial metadata (spacing, origin) from original files
#
# ### This notebook will cover:
# - CT windowing (bone window, soft tissue window)
# - Resampling to isotropic spacing
# - Region cropping
# - Before/after comparisons
# - Saving preprocessed output
#
# **These operations are only meaningful on CT intensity data, NOT on segmentation labels.**

# %%
# This notebook will be implemented after data verification is complete.
# See 01_dataset_exploration.ipynb first.
print("Preprocessing demo — pending data verification.")
print("Please complete notebook 01 first.")
